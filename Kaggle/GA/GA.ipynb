# %%
import os
import json
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook

# Displaying pd Dataframe options
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', 1000)

# %%
# %%time
train_df = pd.read_csv('train.csv')
test_df = pd.read_csv("test.csv")
# Out:
# <string>:2: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
# CPU times: user 19.8 s, sys: 1.54 s, total: 21.3 s
# Wall time: 21.7 s

# %%
def convert_string_jsons(df, jsons_columns=['device', 'geoNetwork', 'totals', 'trafficSource']):
    for column in jsons_columns:
        df[column] = df[column].apply(lambda x: json.loads(x))

convert_string_jsons(train_df)
convert_string_jsons(test_df)

# %%
def exctract(x, key):
    try:
        return x[key]
    except KeyError:
        return 'no_key'


def flatten(df):
    jsons_columns = [column for column in df.columns if type(df[column].values[0]) == dict]    
    
    if len(jsons_columns) > 0:
        for column in tqdm_notebook(jsons_columns):
            keys_set = set()
            for v in df[column].values:
                keys_set = keys_set.union(v.keys())
            for key in list(keys_set):
                print(key)
                df[key] = [exctract(x, key) for x in df[column]]
        df.drop(jsons_columns, axis=1, inplace=True)
        flatten(df)
        
    else:
        return None

# %%
flatten(train_df)
train_df.head()
# Out:
# A Jupyter Widget
# screenResolution
# mobileInputSelector
# browserVersion
# isMobile
# mobileDeviceMarketingName
# browser
# mobileDeviceInfo
# deviceCategory
# operatingSystemVersion
# mobileDeviceModel
# screenColors
# flashVersion
# language
# browserSize
# operatingSystem
# mobileDeviceBranding
# country
# metro
# longitude
# region
# cityId
# networkLocation
# subContinent
# latitude
# city
# networkDomain
# continent
# pageviews
# hits
# visits
# newVisits
# transactionRevenue
# bounces
# medium
# keyword
# adContent
# campaign
# adwordsClickInfo
# source
# isTrueDirect
# referralPath
# campaignCode
# A Jupyter Widget
# page
# adNetworkType
# isVideoAd
# slot
# criteriaParameters
# gclId
# targetingCriteria
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20160902  1131660440785968503
# 1  Organic Search  20160902   377306020877927890
# 2  Organic Search  20160902  3895546263509774583
# 3  Organic Search  20160902  4763447161404445595
# 4  Organic Search  20160902    27294437909732085
#
#                         sessionId  socialEngagementType     visitId  \
# 0  1131660440785968503_1472830385  Not Socially Engaged  1472830385
# 1   377306020877927890_1472880147  Not Socially Engaged  1472880147
# 2  3895546263509774583_1472865386  Not Socially Engaged  1472865386
# 3  4763447161404445595_1472881213  Not Socially Engaged  1472881213
# 4    27294437909732085_1472822600  Not Socially Engaged  1472822600
#
#    visitNumber  visitStartTime               screenResolution  \
# 0            1      1472830385  not available in demo dataset
# 1            1      1472880147  not available in demo dataset
# 2            1      1472865386  not available in demo dataset
# 3            1      1472881213  not available in demo dataset
# 4            2      1472822600  not available in demo dataset
#
#              mobileInputSelector        ...        isTrueDirect  referralPath  \
# 0  not available in demo dataset        ...              no_key        no_key
# 1  not available in demo dataset        ...              no_key        no_key
# 2  not available in demo dataset        ...              no_key        no_key
# 3  not available in demo dataset        ...              no_key        no_key
# 4  not available in demo dataset        ...                True        no_key
#
#   campaignCode    page adNetworkType isVideoAd    slot  \
# 0       no_key  no_key        no_key    no_key  no_key
# 1       no_key  no_key        no_key    no_key  no_key
# 2       no_key  no_key        no_key    no_key  no_key
# 3       no_key  no_key        no_key    no_key  no_key
# 4       no_key  no_key        no_key    no_key  no_key
#
#               criteriaParameters   gclId targetingCriteria
# 0  not available in demo dataset  no_key            no_key
# 1  not available in demo dataset  no_key            no_key
# 2  not available in demo dataset  no_key            no_key
# 3  not available in demo dataset  no_key            no_key
# 4  not available in demo dataset  no_key            no_key
#
# [5 rows x 56 columns]

# %%
flatten(test_df)
test_df.head()
# Out:
# A Jupyter Widget
# screenResolution
# mobileInputSelector
# browserVersion
# isMobile
# mobileDeviceMarketingName
# browser
# mobileDeviceInfo
# deviceCategory
# operatingSystemVersion
# mobileDeviceModel
# screenColors
# flashVersion
# language
# browserSize
# operatingSystem
# mobileDeviceBranding
# country
# metro
# longitude
# region
# cityId
# networkLocation
# subContinent
# latitude
# city
# networkDomain
# continent
# pageviews
# hits
# visits
# newVisits
# bounces
# medium
# keyword
# adContent
# campaign
# adwordsClickInfo
# source
# isTrueDirect
# referralPath
# A Jupyter Widget
# page
# adNetworkType
# isVideoAd
# slot
# criteriaParameters
# gclId
# targetingCriteria
#   channelGrouping      date        fullVisitorId  \
# 0  Organic Search  20171016  6167871330617112363
# 1  Organic Search  20171016  0643697640977915618
# 2  Organic Search  20171016  6059383810968229466
# 3  Organic Search  20171016  2376720078563423631
# 4  Organic Search  20171016  2314544520795440038
#
#                         sessionId  socialEngagementType     visitId  \
# 0  6167871330617112363_1508151024  Not Socially Engaged  1508151024
# 1  0643697640977915618_1508175522  Not Socially Engaged  1508175522
# 2  6059383810968229466_1508143220  Not Socially Engaged  1508143220
# 3  2376720078563423631_1508193530  Not Socially Engaged  1508193530
# 4  2314544520795440038_1508217442  Not Socially Engaged  1508217442
#
#    visitNumber  visitStartTime               screenResolution  \
# 0            2      1508151024  not available in demo dataset
# 1            1      1508175522  not available in demo dataset
# 2            1      1508143220  not available in demo dataset
# 3            1      1508193530  not available in demo dataset
# 4            1      1508217442  not available in demo dataset
#
#              mobileInputSelector        ...         source  isTrueDirect  \
# 0  not available in demo dataset        ...         google          True
# 1  not available in demo dataset        ...         google        no_key
# 2  not available in demo dataset        ...         google        no_key
# 3  not available in demo dataset        ...         google        no_key
# 4  not available in demo dataset        ...         google        no_key
#
#   referralPath    page adNetworkType isVideoAd    slot  \
# 0       no_key  no_key        no_key    no_key  no_key
# 1       no_key  no_key        no_key    no_key  no_key
# 2       no_key  no_key        no_key    no_key  no_key
# 3       no_key  no_key        no_key    no_key  no_key
# 4       no_key  no_key        no_key    no_key  no_key
#
#               criteriaParameters   gclId targetingCriteria
# 0  not available in demo dataset  no_key            no_key
# 1  not available in demo dataset  no_key            no_key
# 2  not available in demo dataset  no_key            no_key
# 3  not available in demo dataset  no_key            no_key
# 4  not available in demo dataset  no_key            no_key
#
# [5 rows x 54 columns]

# %%
train_df.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'screenResolution', 'mobileInputSelector', 'browserVersion', 'isMobile',
#        'mobileDeviceMarketingName', 'browser', 'mobileDeviceInfo',
#        'deviceCategory', 'operatingSystemVersion', 'mobileDeviceModel',
#        'screenColors', 'flashVersion', 'language', 'browserSize',
#        'operatingSystem', 'mobileDeviceBranding', 'country', 'metro',
#        'longitude', 'region', 'cityId', 'networkLocation', 'subContinent',
#        'latitude', 'city', 'networkDomain', 'continent', 'pageviews', 'hits',
#        'visits', 'newVisits', 'transactionRevenue', 'bounces', 'medium',
#        'keyword', 'adContent', 'campaign', 'source', 'isTrueDirect',
#        'referralPath', 'campaignCode', 'page', 'adNetworkType', 'isVideoAd',
#        'slot', 'criteriaParameters', 'gclId', 'targetingCriteria'],
#       dtype='object')

# %%
test_df.columns
# Out:
# Index(['channelGrouping', 'date', 'fullVisitorId', 'sessionId',
#        'socialEngagementType', 'visitId', 'visitNumber', 'visitStartTime',
#        'screenResolution', 'mobileInputSelector', 'browserVersion', 'isMobile',
#        'mobileDeviceMarketingName', 'browser', 'mobileDeviceInfo',
#        'deviceCategory', 'operatingSystemVersion', 'mobileDeviceModel',
#        'screenColors', 'flashVersion', 'language', 'browserSize',
#        'operatingSystem', 'mobileDeviceBranding', 'country', 'metro',
#        'longitude', 'region', 'cityId', 'networkLocation', 'subContinent',
#        'latitude', 'city', 'networkDomain', 'continent', 'pageviews', 'hits',
#        'visits', 'newVisits', 'bounces', 'medium', 'keyword', 'adContent',
#        'campaign', 'source', 'isTrueDirect', 'referralPath', 'page',
#        'adNetworkType', 'isVideoAd', 'slot', 'criteriaParameters', 'gclId',
#        'targetingCriteria'],
#       dtype='object')

# %%
set(train_df.columns).difference(set(test_df.columns))
# Out:
# {'transactionRevenue'}

# %%
set(test_df.columns).difference(set(train_df.columns))
# Out:
# set()

# %%
train_df.drop(['campaignCode'], axis=1, inplace=True)

# %%
# Prints columns and df name if more than one type in column
# Returns columns name list with doubles in types 
def itter_types(df, dfname):

    def check_types(df, column):
        types = []
        for elem in df[column]:
            if type(elem) not in types:
                types.append(type(elem))
        return types

    result = []
    for column in df:
        r = check_types(df, column)
        if len(r) > 1:
            result.append(column)
            print('MORE THAN ONE TYPES IN {}'.format(dfname), column, r)
    return result

train_column_list_doubles = itter_types(train_df, 'train_df')
test_column_list_doubles = itter_types(test_df, 'test_df')

# %%
train_column_list_doubles
test_column_list_doubles
# Out:
# []

# %%
def merge_types(df, column_name):
    values = []
    
    for elem in df[column_name]:
        if column_name == 'fullVisitorId':
            if isinstance(elem, int):
                values.append(str(elem))
            else:
                values.append(elem)
        if column_name == 'isTrueDirect':
            if isinstance(elem, bool):
                values.append(str(elem))
            else:
                values.append(elem)
        if column_name == 'isVideoAd':
            if isinstance(elem, bool):
                values.append(str(elem))
            else:
                values.append(elem)
        if column_name == 'targetingCriteria':
            if isinstance(elem, dict):
                values.append('empty_dict')
            else:
                values.append(elem)
            
    df[column_name] = pd.Series(values)

doubles = ['fullVisitorId', 'isTrueDirect', 'isVideoAd', 'targetingCriteria']

for double in doubles:
    merge_types(train_df, double)
    merge_types(test_df, double)

# %%
itter_types(train_df, 'train_df')
itter_types(test_df, 'test_df')
# Out:
# []

# %%
train_df.head()
# Out:
#   channelGrouping      date        fullVisitorId                       sessionId  socialEngagementType     visitId  visitNumber  visitStartTime               screenResolution            mobileInputSelector                 browserVersion  isMobile      mobileDeviceMarketingName     browser               mobileDeviceInfo deviceCategory         operatingSystemVersion              mobileDeviceModel                   screenColors                   flashVersion                       language                    browserSize operatingSystem           mobileDeviceBranding         country                          metro                      longitude                         region                         cityId                networkLocation     subContinent                       latitude                           city    networkDomain continent pageviews hits visits newVisits transactionRevenue bounces   medium          keyword adContent   campaign  source isTrueDirect referralPath    page  \
# 0  Organic Search  20160902  1131660440785968503  1131660440785968503_1472830385  Not Socially Engaged  1472830385            1      1472830385  not available in demo dataset  not available in demo dataset  not available in demo dataset     False  not available in demo dataset      Chrome  not available in demo dataset        desktop  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset         Windows  not available in demo dataset          Turkey                      (not set)  not available in demo dataset                          Izmir  not available in demo dataset  not available in demo dataset     Western Asia  not available in demo dataset                          Izmir     ttnet.com.tr      Asia         1    1      1         1             no_key       1  organic   (not provided)    no_key  (not set)  google       no_key       no_key  no_key
# 1  Organic Search  20160902   377306020877927890   377306020877927890_1472880147  Not Socially Engaged  1472880147            1      1472880147  not available in demo dataset  not available in demo dataset  not available in demo dataset     False  not available in demo dataset     Firefox  not available in demo dataset        desktop  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset       Macintosh  not available in demo dataset       Australia  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset      Australasia  not available in demo dataset  not available in demo dataset      dodo.net.au   Oceania         1    1      1         1             no_key       1  organic   (not provided)    no_key  (not set)  google       no_key       no_key  no_key
# 2  Organic Search  20160902  3895546263509774583  3895546263509774583_1472865386  Not Socially Engaged  1472865386            1      1472865386  not available in demo dataset  not available in demo dataset  not available in demo dataset     False  not available in demo dataset      Chrome  not available in demo dataset        desktop  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset         Windows  not available in demo dataset           Spain                      (not set)  not available in demo dataset            Community of Madrid  not available in demo dataset  not available in demo dataset  Southern Europe  not available in demo dataset                         Madrid  unknown.unknown    Europe         1    1      1         1             no_key       1  organic   (not provided)    no_key  (not set)  google       no_key       no_key  no_key
# 3  Organic Search  20160902  4763447161404445595  4763447161404445595_1472881213  Not Socially Engaged  1472881213            1      1472881213  not available in demo dataset  not available in demo dataset  not available in demo dataset     False  not available in demo dataset  UC Browser  not available in demo dataset        desktop  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset           Linux  not available in demo dataset       Indonesia  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset   Southeast Asia  not available in demo dataset  not available in demo dataset  unknown.unknown      Asia         1    1      1         1             no_key       1  organic  google + online    no_key  (not set)  google       no_key       no_key  no_key
# 4  Organic Search  20160902    27294437909732085    27294437909732085_1472822600  Not Socially Engaged  1472822600            2      1472822600  not available in demo dataset  not available in demo dataset  not available in demo dataset      True  not available in demo dataset      Chrome  not available in demo dataset         mobile  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset         Android  not available in demo dataset  United Kingdom  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  not available in demo dataset  Northern Europe  not available in demo dataset  not available in demo dataset  unknown.unknown    Europe         1    1      1    no_key             no_key       1  organic   (not provided)    no_key  (not set)  google         True       no_key  no_key
#
#   adNetworkType isVideoAd    slot             criteriaParameters   gclId targetingCriteria
# 0        no_key    no_key  no_key  not available in demo dataset  no_key            no_key
# 1        no_key    no_key  no_key  not available in demo dataset  no_key            no_key
# 2        no_key    no_key  no_key  not available in demo dataset  no_key            no_key
# 3        no_key    no_key  no_key  not available in demo dataset  no_key            no_key
# 4        no_key    no_key  no_key  not available in demo dataset  no_key            no_key

# %%
constants = [column for column in train_df.columns if len(train_df[column].value_counts()) < 2 ]
constants
# Out:
# ['socialEngagementType',
#  'screenResolution',
#  'mobileInputSelector',
#  'browserVersion',
#  'mobileDeviceMarketingName',
#  'mobileDeviceInfo',
#  'operatingSystemVersion',
#  'mobileDeviceModel',
#  'screenColors',
#  'flashVersion',
#  'language',
#  'browserSize',
#  'mobileDeviceBranding',
#  'longitude',
#  'cityId',
#  'networkLocation',
#  'latitude',
#  'visits',
#  'criteriaParameters']

# %%
train_df.drop(constants, axis=1, inplace=True)
test_df.drop(constants, axis=1, inplace=True)

# %%
train_df.head()
# Out:
#   channelGrouping      date        fullVisitorId                       sessionId     visitId  visitNumber  visitStartTime  isMobile     browser deviceCategory operatingSystem         country                          metro                         region     subContinent                           city    networkDomain continent pageviews hits newVisits transactionRevenue bounces   medium          keyword adContent   campaign  source isTrueDirect referralPath    page adNetworkType isVideoAd    slot   gclId targetingCriteria
# 0  Organic Search  20160902  1131660440785968503  1131660440785968503_1472830385  1472830385            1      1472830385     False      Chrome        desktop         Windows          Turkey                      (not set)                          Izmir     Western Asia                          Izmir     ttnet.com.tr      Asia         1    1         1             no_key       1  organic   (not provided)    no_key  (not set)  google       no_key       no_key  no_key        no_key    no_key  no_key  no_key            no_key
# 1  Organic Search  20160902   377306020877927890   377306020877927890_1472880147  1472880147            1      1472880147     False     Firefox        desktop       Macintosh       Australia  not available in demo dataset  not available in demo dataset      Australasia  not available in demo dataset      dodo.net.au   Oceania         1    1         1             no_key       1  organic   (not provided)    no_key  (not set)  google       no_key       no_key  no_key        no_key    no_key  no_key  no_key            no_key
# 2  Organic Search  20160902  3895546263509774583  3895546263509774583_1472865386  1472865386            1      1472865386     False      Chrome        desktop         Windows           Spain                      (not set)            Community of Madrid  Southern Europe                         Madrid  unknown.unknown    Europe         1    1         1             no_key       1  organic   (not provided)    no_key  (not set)  google       no_key       no_key  no_key        no_key    no_key  no_key  no_key            no_key
# 3  Organic Search  20160902  4763447161404445595  4763447161404445595_1472881213  1472881213            1      1472881213     False  UC Browser        desktop           Linux       Indonesia  not available in demo dataset  not available in demo dataset   Southeast Asia  not available in demo dataset  unknown.unknown      Asia         1    1         1             no_key       1  organic  google + online    no_key  (not set)  google       no_key       no_key  no_key        no_key    no_key  no_key  no_key            no_key
# 4  Organic Search  20160902    27294437909732085    27294437909732085_1472822600  1472822600            2      1472822600      True      Chrome         mobile         Android  United Kingdom  not available in demo dataset  not available in demo dataset  Northern Europe  not available in demo dataset  unknown.unknown    Europe         1    1    no_key             no_key       1  organic   (not provided)    no_key  (not set)  google         True       no_key  no_key        no_key    no_key  no_key  no_key            no_key

# %%
# Checks if columns are equal
# Построить полный граф в будущем
sum(train_df['visitId'] == train_df['visitStartTime'])
# Out:
# 898944

# %%
# Sorted by time because Catboost more efficient on sorted dataframes by time features
train_df = train_df.sort_values(by=['visitStartTime'])

# %%
# Check if test and train is parted by time and not mixed-time
# Gets more understanding of the contest organizers ideas
train_df['visitStartTime'].max() <= test_df['visitStartTime'].min()
# Out:
# True

# %%
# Tranform target value with natural log. 
# important that log(0) not exist that is why we put 1 instead of 0
# after log procedure passed log(1) becomes 0.0
train_df['transactionRevenue'] = np.log(train_df['transactionRevenue'].replace('no_key',1).astype(int))

# %%
# Displaing features. Helps for ideas generation and feature engeneering
# Good for understandig the data
for column in train_df.columns:
    print(train_df[column].value_counts().head(), '\n')
# Out:
# Organic Search    381561
# Social            226117
# Direct            143026
# Referral          104838
# Paid Search        25326
# Name: channelGrouping, dtype: int64
#
# 20161128    4807
# 20161115    4685
# 20161114    4466
# 20161130    4435
# 20161026    4375
# Name: date, dtype: int64
#
# 1957458976293878100    278
# 824839726118485274     205
# 3608475193341679870    201
# 1856749147915772585    199
# 3269834865385146569    155
# Name: fullVisitorId, dtype: int64
#
# 8289905218281015480_1489219054    2
# 8512858492750142543_1474611975    2
# 1468326551501903507_1480492763    2
# 8326820442788571166_1483515526    2
# 0098453420096961116_1498458618    2
# Name: sessionId, dtype: int64
#
# 1493146175    8
# 1478345904    6
# 1481369525    6
# 1484649802    6
# 1500856602    5
# Name: visitId, dtype: int64
#
# 1    703060
# 2     92548
# 3     35843
# 4     19157
# 5     11615
# Name: visitNumber, dtype: int64
#
# 1493146175    8
# 1481369525    6
# 1478345904    6
# 1484649802    6
# 1500856602    5
# Name: visitStartTime, dtype: int64
#
# False    664530
# True     239123
# Name: isMobile, dtype: int64
#
# Chrome               620364
# Safari               182245
# Firefox               37069
# Internet Explorer     19375
# Edge                  10205
# Name: browser, dtype: int64
#
# desktop    664479
# mobile     208725
# tablet      30449
# Name: deviceCategory, dtype: int64
#
# Windows      350072
# Macintosh    253938
# Android      123892
# iOS          107665
# Linux         35034
# Name: operatingSystem, dtype: int64
#
# United States     364744
# India              51140
# United Kingdom     37393
# Canada             25869
# Vietnam            24598
# Name: country, dtype: int64
#
# not available in demo dataset        508229
# (not set)                            201766
# San Francisco-Oakland-San Jose CA     95913
# New York NY                           26917
# London                                12571
# Name: metro, dtype: int64
#
# not available in demo dataset    508229
# California                       107495
# (not set)                         27827
# New York                          26433
# England                           13198
# Name: region, dtype: int64
#
# Northern America    390657
# Southeast Asia       77800
# Southern Asia        59321
# Western Europe       59114
# Northern Europe      58168
# Name: subContinent, dtype: int64
#
# not available in demo dataset    508229
# Mountain View                     40884
# (not set)                         34262
# New York                          26371
# San Francisco                     20329
# Name: city, dtype: int64
#
# (not set)          244881
# unknown.unknown    146034
# comcast.net         28743
# rr.com              14827
# verizon.net         13637
# Name: networkDomain, dtype: int64
#
# Americas    450377
# Asia        223698
# Europe      198311
# Oceania      15054
# Africa       14745
# Name: continent, dtype: int64
#
# 1    452522
# 2    143770
# 3     73835
# 4     45192
# 5     33411
# Name: pageviews, dtype: int64
#
# 1    446754
# 2    137952
# 3     70402
# 4     42444
# 5     30939
# Name: hits, dtype: int64
#
# 1         703060
# no_key    200593
# Name: newVisits, dtype: int64
#
# 0.000000     892138
# 16.648135       256
# 16.759423       189
# 17.329739       187
# 17.617495       170
# Name: transactionRevenue, dtype: int64
#
# no_key    453023
# 1         450630
# Name: bounces, dtype: int64
#
# organic      381561
# referral     330955
# (none)       143026
# cpc           25326
# affiliate     16403
# Name: medium, dtype: int64
#
# no_key                             502929
# (not provided)                     366363
# 6qEhsCssdK0z36ri                    11503
# (Remarketing/Content targeting)      2298
# 1hZbAqLCbjwfgOH7                     2264
# Name: keyword, dtype: int64
#
# no_key                           892707
# Google Merchandise Collection      5122
# Google Online Store                1245
# Display Ad created 3/11/14          967
# Full auto ad IMAGE ONLY             822
# Name: adContent, dtype: int64
#
# (not set)                             865347
# Data Share Promo                       16403
# AW - Dynamic Search Ads Whole Site     14244
# AW - Accessories                        7070
# test-liyuhz                              392
# Name: campaign, dtype: int64
#
# google                 400788
# youtube.com            212602
# (direct)               143028
# mall.googleplex.com     66416
# Partners                16411
# Name: source, dtype: int64
#
# no_key    629648
# True      274005
# Name: isTrueDirect, dtype: int64
#
# no_key             572712
# /                   75523
# /yt/about/          71036
# /analytics/web/     14620
# /yt/about/tr/       14599
# Name: referralPath, dtype: int64
#
# no_key    882193
# 1          21362
# 2             73
# 3             10
# 5              7
# Name: page, dtype: int64
#
# no_key             882193
# Google Search       21453
# Search partners         7
# Name: adNetworkType, dtype: int64
#
# no_key    882193
# False      21460
# Name: isVideoAd, dtype: int64
#
# no_key    882193
# Top        20956
# RHS          504
# Name: slot, dtype: int64
#
# no_key                                                                                        882092
# Cj0KEQjwmIrJBRCRmJ_x7KDo-9oBEiQAuUPKMufMpuG3ZdwYO8GTsjiBFd5MPHStZa9y_9NCrI8X97oaAglc8P8HAQ        70
# Cj0KEQjw1ee_BRD3hK6x993YzeoBEiQA5RH_BEA562M9tvl_mtnAFvtDnDqOQRp1RvxMMgwjcX1LAfwaAj4o8P8HAQ        41
# CJH1vbf94M8CFUElgQodyakHgQ                                                                        29
# Cj0KEQiAw_DEBRChnYiQ_562gsEBEiQA4LcssmB_RWgvpPnltzlzj5rGwqx5lk87wC5CjfcqzneNZewaAiAp8P8HAQ        27
# Name: gclId, dtype: int64
#
# no_key        902193
# empty_dict      1460
# Name: targetingCriteria, dtype: int64

# %%
cat_features = ['channelGrouping','isMobile','browser','deviceCategory','operatingSystem',
               'country','region','subContinent','networkDomain','continent','newVisits',
               'medium', 'isTrueDirect', 'source', 'isVideoAd', 'slot','page']
num_features = ['visitNumber','pageviews','hits']

# %%
shape = train_df.shape[0]
X_train, X_test = train_df.iloc[:int(shape*0.7),:], train_df.iloc[int(shape*0.7):,:]
y_train, y_test = X_train['transactionRevenue'], X_test['transactionRevenue']

X_train, X_test = X_train[cat_features+num_features], X_test[cat_features+num_features]

X_train[num_features] = X_train[num_features].replace('no_key',0)
X_test[num_features] = X_test[num_features].replace('no_key',0)

# %%
categorical_features=[i for i, x in enumerate(X_train.columns) if x in cat_features]

# %%
from catboost import CatBoostRegressor

# %%
model_Cat = CatBoostRegressor(iterations=100, thread_count=4, 
                             depth=6, border_count=100, has_time=True,
                             counter_calc_method='SkipTest')

# %%
model_Cat.fit(X_train, y_train, cat_features=categorical_features)
# Out:
# 0:	learn: 1.9262229	total: 1.51s	remaining: 2m 29s
# 1:	learn: 1.9113713	total: 2.72s	remaining: 2m 13s
# 2:	learn: 1.8974432	total: 3.89s	remaining: 2m 5s
# 3:	learn: 1.8840654	total: 4.98s	remaining: 1m 59s
# 4:	learn: 1.8714065	total: 6.04s	remaining: 1m 54s
# 5:	learn: 1.8592806	total: 7.13s	remaining: 1m 51s
